# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(dpi=100)

# %matplotlib inline

# %%
df = pd.read_csv('end_data.csv').drop(['Unnamed: 0'], axis = 1)

# %%
df
# Out:
#                                          smiles string  affinity value
# 0                     COc1ccc(cc1)C(=O)n1nc(C)c(Br)c1C     2842.408920
# 1             Oc1ccc(c(O)c1)-c1oc2cc(O)cc(O)c2c(=O)c1O     2988.260716
# 2    Cc1ccc(Cn2c3nc4ccccn4c(=O)c3cc(C(=O)NCc3ccco3)...     3141.535721
# 3       Nc1c(C(=O)NCCN2CCOCC2)c2nc3ccccc3nc2n1Cc1ccco1     6491.508240
# 4              CN1CCc2cccc-3c2[C@@H]1Cc1ccc(O)c(O)c-31      400.000000
# ..                                                 ...             ...
# 568  CC1CC(=O)c2c(O1)cc1c(c(O)cc(O)c1c2O)-c1c(O)cc(...     1491.895432
# 569  O[C@@H]1[C@H]2COC(=O)c3cc(O)c(O)c(O)c3-c3c(O)c...     4484.900978
# 570  O=C(COC(=O)c1cc(nc2ccccc12)-c1ccco1)NCc1ccc2OC...      400.000000
# 571                 Cn1cnnc1SCC(=O)Nc1sc2CCCc2c1C(N)=O     3160.825126
# 572  C[C@@H](CNC(=O)c1c(O)c(O)cc2c(O)c(c(C)cc12)-c1...      200.000000
#
# [573 rows x 2 columns]

# %%
plt.rcParams["figure.figsize"] = (15,5)

plt.plot(list(range(len(df['affinity value']))), sorted(list(df['affinity value'])))

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

plt.figure(figsize=(16, 6))

g = sns.jointplot(x = list(range(len(df['affinity value']))), y = sorted(list(df['affinity value'])),
                  kind="reg", truncate=False, 
                  color="m")
